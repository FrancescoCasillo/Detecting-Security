# %%
import json
import pandas as pd
import numpy as np
import os

# %%
data = []
with open('.\Dataset\SecurityDiscoverer_classified_sentences.arff', "r") as f:
    for line in f:
        line = line.replace('\n', '')
        data.append(line.split(','))

securityAspects = ['Confidentiality', 'Integrity', 'Availability', 'Identification & Authentication', 'Accountability', 'Privacy']
    
df = pd.DataFrame(data)
df[12:]
# Out:
#         0    1    2    3    4   5               6   \
# 12      no   no   no   no   no  no  oscar_requests
# 13      no   no   no   no   no  no  oscar_requests
# 14      no   no   no   no   no  no  oscar_requests
# 15      no   no   no  yes  yes  no  oscar_requests
# 16      no   no   no   no   no  no  oscar_requests
# ...    ...  ...  ...  ...  ...  ..             ...
# 10970  yes   no   no  yes   no  no           CCHIT
# 10971  yes   no  yes   no  yes  no           CCHIT
# 10972   no  yes   no   no   no  no           CCHIT
# 10973   no  yes   no   no   no  no           CCHIT
# 10974   no  yes  yes   no   no  no           CCHIT
#
#                                                       7     8     9     10
# 12                                               summary  None  None  None
# 13                                                detail  None  None  None
# 14                                                  text  None  None  None
# ...

# %%
new_dataset = pd.DataFrame(index=np.arange(df[12:].shape[0]))

new_dataset["Requirement Text"] = None
new_dataset["Security Related"] = False

for aspect in securityAspects:
    new_dataset[aspect] = False

counter = 0
for row in df[12:].iterrows():
    new_dataset.loc[counter,"Requirement Text"] = row[1][7]
    if row[1][0] == 'yes':
        new_dataset.loc[counter,"Security Related"] = True
        new_dataset.loc[counter,securityAspects[0]] = True

    elif row[1][1] == 'yes':
        new_dataset.loc[counter,"Security Related"] = True
        new_dataset.loc[counter,securityAspects[1]] = True

    elif row[1][2] == 'yes':
        new_dataset.loc[counter,"Security Related"] = True
        new_dataset.loc[counter,securityAspects[2]] = True

    elif row[1][3] == 'yes':
        new_dataset.loc[counter,"Security Related"] = True
        new_dataset.loc[counter,securityAspects[3]] = True

    elif row[1][4] == 'yes':
        new_dataset.loc[counter,"Security Related"] = True
        new_dataset.loc[counter,securityAspects[4]] = True

    elif row[1][5] == 'yes':
        new_dataset.loc[counter,"Security Related"] = True
        new_dataset.loc[counter,securityAspects[5]] = True
    counter += 1

new_dataset
# Out:
#                                         Requirement Text  Security Related  \
# 0                                                summary             False
# 1                                                 detail             False
# 2                                                   text             False
# 3      'set demographic check myoscar username should...              True
# 4      '= = = = = = = = = = = = = = = = = = = = = = =...             False
# ...                                                  ...               ...
# 10958  'display system access prior to phi any shall ...              True
# 10959  'able system shall be generate to backup copy ...              True
# 10960  'result system restore functionality shall sta...              True
# 10961  'include state this shall restoration applicat...              True
# 10962  'have claim if system available to be 24 7 the...              True
#
#        Confidentiality  Integrity  Availability  \
# ...

# %%
new_dataset.to_excel('.\Dataset\Requirements.xlsx',index=False)
